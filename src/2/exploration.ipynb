# %%
import pandas as pd

# %%
data_path = '../../datasets/premier/{season}.csv'
# we will use the same dataframes for all the seasons
dfs = {}

for season in range(15, 26):
    dfs[season] = pd.read_csv(data_path.format(season=season))

# concatenate all the dataframes
df = pd.concat(dfs.values(), ignore_index=True, axis=0)

# %%
# get info about the dataframe
df.describe()
# Out:
#               FTHG         FTAG         HTHG         HTAG           HS  \
# count  4051.000000  4051.000000  4051.000000  4051.000000  4051.000000
# mean      1.550975     1.269810     0.703777     0.565539    14.060726
# std       1.315456     1.205758     0.855849     0.774812     5.731289
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000    10.000000
# 50%       1.000000     1.000000     0.000000     0.000000    13.000000
# 75%       2.000000     2.000000     1.000000     1.000000    17.000000
# max       9.000000     9.000000     5.000000     5.000000    43.000000
#
#                 AS          HST          AST           HF           AF  ...  \
# count  4051.000000  4051.000000  4051.000000  4051.000000  4051.000000  ...
# mean     11.495927     4.802024     4.003456    10.601086    10.941002  ...
# std       4.972534     2.638613     2.340937     3.450438     3.597355  ...
# ...

# %%
df.columns.to_list()
# Out:
# ['Div',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Referee',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'LBH',
#  'LBD',
#  'LBA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'SJH',
#  'SJD',
#  'SJA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'Bb1X2',
#  'BbMxH',
#  'BbAvH',
#  'BbMxD',
#  'BbAvD',
#  'BbMxA',
#  'BbAvA',
#  'BbOU',
#  'BbMx>2.5',
#  'BbAv>2.5',
#  'BbMx<2.5',
#  'BbAv<2.5',
#  'BbAH',
#  'BbAHh',
#  'BbMxAHH',
#  'BbAvAHH',
#  'BbMxAHA',
#  'BbAvAHA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'Time',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
# ...

# %%
# get the 40 columns with the most non-null values
df.count().nlargest(50)
# Out:
# Div         4051
# Date        4051
# HomeTeam    4051
# AwayTeam    4051
# FTHG        4051
# FTAG        4051
# FTR         4051
# HTHG        4051
# HTAG        4051
# HTR         4051
# Referee     4051
# HS          4051
# AS          4051
# HST         4051
# AST         4051
# HF          4051
# AF          4051
# HC          4051
# AC          4051
# HY          4051
# AY          4051
# HR          4051
# AR          4051
# B365H       4051
# B365D       4051
# B365A       4051
# PSH         4051
# PSD         4051
# PSA         4051
# WHH         4051
# WHD         4051
# WHA         4051
# PSCH        4051
# PSCD        4051
# PSCA        4051
# BWH         4036
# BWD         4036
# BWA         4036
# VCH         3800
# VCD         3800
# VCA         3800
# IWH         3617
# IWD         3617
# IWA         3617
# Time        2151
# MaxH        2151
# MaxD        2151
# MaxA        2151
# AvgH        2151
# AvgD        2151
# dtype: int64

# %%
reduced_df = df[[
'FTHG',
'FTAG',
'HTHG',
'HTAG',
'HS',
'AS',
'HST',
'AST',
'HF',
'AF',
'HC',
'AC',
'HY',
'AY',
'HR',
'AR', 
'MaxH', 
'MaxD', 
'MaxA', 
'AvgH', 
'AvgD', 
'AvgA',
'B365H',
'B365D',
'B365A',
'BFH',
'BFD',
'BFA',
'PSH',
'PSD',
'PSA',
'WHH',
'WHD',
'WHA',
'Max>2.5',
'Max<2.5',
'Avg>2.5',
'Avg<2.5',
'AHh',
'B365AHH',
'B365AHA',
'PAHH',
'PAHA',
'MaxAHH',
'MaxAHA',
]]

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4052 entries, 0 to 4051
# Data columns (total 45 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   FTHG     4051 non-null   float64
#  1   FTAG     4051 non-null   float64
#  2   HTHG     4051 non-null   float64
#  3   HTAG     4051 non-null   float64
#  4   HS       4051 non-null   float64
#  5   AS       4051 non-null   float64
#  6   HST      4051 non-null   float64
#  7   AST      4051 non-null   float64
#  8   HF       4051 non-null   float64
#  9   AF       4051 non-null   float64
#  10  HC       4051 non-null   float64
#  11  AC       4051 non-null   float64
#  12  HY       4051 non-null   float64
#  13  AY       4051 non-null   float64
#  14  HR       4051 non-null   float64
#  15  AR       4051 non-null   float64
#  16  MaxH     2151 non-null   float64
#  17  MaxD     2151 non-null   float64
#  18  MaxA     2151 non-null   float64
#  19  AvgH     2151 non-null   float64
# ...
